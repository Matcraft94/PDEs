# %% [markdown]
# # Pendulo No Lineal

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.integrate import solve_ivp

# %%
# Definicmos la funcion de solucion
def pendulum(t, state, g, L):
    return [state[1], -g*np.sin(state[0])/L]

# %%
# Configuracion de parametros
g = 9.81
L = 1
t_span = (0.0, 20.0)
t = np.arange(0.0, 20.0, 0.01)
state0 = [1, 0]

# %%
# Obtenemos la solucion
result = solve_ivp(pendulum, t_span, state0, args=(g, L),  
                    dense_output=True, method='LSODA')

# %%
# Graficamos
t = np.linspace(0, 20, 300)
z = result.sol(t)

plt.plot(t, z.T)
# Out:
# [<matplotlib.lines.Line2D at 0x7f159b6c8520>,
#  <matplotlib.lines.Line2D at 0x7f159b6c8700>]
